# %%
 # Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44
# 5                                  Dreamkiss   3.61
# 6     Interrogator, Blood Blade of the Queen   2.18
# 7                              Abyssal Shard   2.67
# 8                                  Souleater   1.10
# 9               Ghastly Adamantite Protector   3.58

# %%
#Player Count: Display the total number of players.
count = len(purchase_data["SN"].value_counts())

#Data frame showing the renamed column and player count
player_count = pd.DataFrame({"Total Players": [count]})

#Align to the left. Reference = https://stackoverflow.com/questions/17232013/how-to-set-the-pandas-dataframe-data-left-right-alignment
player_count = player_count.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

player_count
# Out:
# <style  type="text/css" >
#     #T_57e7a618_a9eb_11ea_87a1_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_57e7a618_a9eb_11ea_87a1_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }</style><table id="T_57e7a618_a9eb_11ea_87a1_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57e7a618_a9eb_11ea_87a1_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_57e7a618_a9eb_11ea_87a1_d0abd51aeb5drow0_col0" class="data row0 col0" >576</td>
#             </tr>
#     </tbody></table>

# %%
#Puchasing Analysis (Total) - Number of Unique Items, Average Purchase Price, Total Number of Purchases, Total Revenue 
unique_items = len(purchase_data["Item ID"].value_counts())
avg_price = purchase_data["Price"].mean()
total_purchases = len(purchase_data["Purchase ID"].value_counts())
total_revenue = purchase_data["Price"].sum()

#Data frame showing purchasing analysis
purchase_analysis = pd.DataFrame({"Number of Unique Items": [unique_items],
                                 "Average Price": [avg_price],
                                 "Number of Purchases": [total_purchases],
                                  "Total Revenue": [total_revenue]})

#Format average price and total revenue to show 2 decimals and the $ sign
purchase_analysis["Average Price"] = purchase_analysis["Average Price"].astype(float).map("${:,.2f}".format)
purchase_analysis["Total Revenue"] = purchase_analysis["Total Revenue"].astype(float).map("${:,.2f}".format)

#Align to the left
purchase_analysis = purchase_analysis.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

purchase_analysis
# Out:
# <style  type="text/css" >
#     #T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col3 {
#             text-align:  left;
#         }</style><table id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col0" class="data row0 col0" >179</td>
#                         <td id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col2" class="data row0 col2" >780</td>
#                         <td id="T_5b2a75ba_a9eb_11ea_a1eb_d0abd51aeb5drow0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %%
#Gender Demographics: Percentage and count of male players, female players, others
#Get the total count of genders by username, do not use total count by gender because there are usernames that repeat'
gender = purchase_data.groupby("Gender")
gender_count = gender.nunique()["SN"]

#Calculate percentage
percentage = (gender.nunique()["SN"] / len(purchase_data["SN"].value_counts())) * 100

#Create dataframe
gender_data_df = pd.DataFrame({"Total Count": gender_count, "Percentage of Players": percentage})


#Format dataframe by assigning percentage and sort function
gender_data_df["Percentage of Players"] = gender_data_df["Percentage of Players"].astype(float).map("{:,.2f}%".format)
gender_data_df = gender_data_df.sort_values(["Total Count"], ascending = False)

#Take out corner index
gender_data_df.index.name = None

#Align to the left
gender_data_df = gender_data_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

gender_data_df
# Out:
# <style  type="text/css" >
#     #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }</style><table id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow0_col0" class="data row0 col0" >484</td>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow1_col0" class="data row1 col0" >81</td>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow1_col1" class="data row1 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow2_col0" class="data row2 col0" >11</td>
#                         <td id="T_6e422d76_a9eb_11ea_9802_d0abd51aeb5drow2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %%
#Purchasing Analysis: Obtain purchase count, average purchase price, purchase total per person by gender
#Purchase count by gender 
purchase_count = gender["Purchase ID"].count()

#Average purchase price by gender
purchase_average = gender["Price"].mean()

#Total sum price by gender
sum_price = gender["Price"].sum()

#Average purchase total per person
average_total = sum_price / gender_count 

#Create dataframe with calculated values
purchase_analysis_df = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": purchase_average,
                                    "Total Purchase Value": sum_price,
                                    "Avg Total Purchase per Person": average_total})

#Format dataframe
purchase_analysis_df["Average Purchase Price"]= purchase_analysis_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
purchase_analysis_df["Total Purchase Value"]= purchase_analysis_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)
purchase_analysis_df["Avg Total Purchase per Person"]= purchase_analysis_df["Avg Total Purchase per Person"].astype(float).map("${:,.2f}".format)

#Align to the left
purchase_analysis_df = purchase_analysis_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

purchase_analysis_df
# Out:
# <style  type="text/css" >
#     #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col3 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col2 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col3 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col2 {
#             text-align:  left;
#         }    #T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col3 {
#             text-align:  left;
#         }</style><table id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col0" class="data row0 col0" >113</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col0" class="data row1 col0" >652</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col0" class="data row2 col0" >15</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_73aa62ae_a9eb_11ea_831b_d0abd51aeb5drow2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
#Age Demographics: Establish bins for ages
#Figure out max and min age for bins
(purchase_data["Age"].max())
(purchase_data["Age"].min())
#Max age = 45, min age = 7 

#Create bins
bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]

#Groups
group_label = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#Slice the data and place it into bins
age_demographics = purchase_data
age_demographics["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=group_label)

#Group by age
summary = age_demographics.groupby("Age Ranges")

#Calculate total count 
total_age_count = summary["SN"].nunique()

#Calculate percentage
age_percentage = (summary["SN"].nunique()/len(purchase_data["SN"].value_counts())) * 100
age_percentage

#Create dataframe with calculated values
age_demographics_df = pd.DataFrame({"Total Count": total_age_count,
                                   "Percentage of Players": age_percentage})

#Format dataframe
age_demographics_df["Percentage of Players"] = age_demographics_df["Percentage of Players"].astype(float).map("{:,.2f}%".format)

#Get rid of index
age_demographics_df.index.name = None

#Align to the left 
age_demographics_df = age_demographics_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

age_demographics_df
# Out:
# <style  type="text/css" >
#     #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow3_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow3_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow4_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow4_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow5_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow5_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow6_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow6_col1 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow7_col0 {
#             text-align:  left;
#         }    #T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow7_col1 {
#             text-align:  left;
#         }</style><table id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow1_col0" class="data row1 col0" >22</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow2_col0" class="data row2 col0" >107</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow3_col0" class="data row3 col0" >258</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow4_col0" class="data row4 col0" >77</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow5_col0" class="data row5 col0" >52</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow6_col0" class="data row6 col0" >31</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5dlevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow7_col0" class="data row7 col0" >12</td>
#                         <td id="T_7b432e4a_a9eb_11ea_8bf2_d0abd51aeb5drow7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
#Purchasing Analysis by Age
#Calculate purchase count
purchase_count_age = summary["SN"].count()

#Calculate average purchase price
purchase_average_age = summary["Price"].mean()

#Calculate total sum
purchase_total_age = summary["Price"].sum()
purchase_total_age

#Calculate average total purchase per person (.nunique())
average_total_age = purchase_total_age / total_age_count 

#Create dataframe with calculated values
age_analysis_df = pd.DataFrame({"Purchase Count": purchase_count_age,
                               "Average Purchase Price": purchase_average_age,
                               "Total Purchase Value": purchase_total_age,
                               "Avg Total Purchase per Person": average_total_age})

#Format dataframe 
age_analysis_df["Average Purchase Price"]= age_analysis_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
age_analysis_df["Total Purchase Value"]= age_analysis_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)
age_analysis_df["Avg Total Purchase per Person"]= age_analysis_df["Avg Total Purchase per Person"].astype(float).map("${:,.2f}".format)

#Add index back 
age_analysis_df.index.name = "Age Ranges"

#Align to the left
age_analysis_df = age_analysis_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

age_analysis_df
# Out:
# <style  type="text/css" >
#     #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col3 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow7_col0 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow7_col1 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow7_col2 {
#             text-align:  left;
#         }    #T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow7_col3 {
#             text-align:  left;
#         }</style><table id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col0" class="data row0 col0" >23</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col0" class="data row1 col0" >28</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col0" class="data row2 col0" >136</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col0" class="data row3 col0" >365</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col0" class="data row4 col0" >101</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col0" class="data row5 col0" >73</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5dlevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col0" class="data row6 col0" >41</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_804224fa_a9eb_11ea_90ba_d0abd51aeb5drow6_col2" class="data row6 col

# %%
#Top Spenders Analysis
#Create a group using "SN"
top_spenders = purchase_data.groupby("SN")

#Purchase count
spenders_count = top_spenders["SN"].count()

#Average purchase price 
spenders_average = top_spenders["Price"].mean()

#Total purchase value
spenders_total = top_spenders ["Price"].sum()

#Create dataframe with calculated values
spenders_df = pd.DataFrame({"Purchase Count": spenders_count,
                           "Average Purchase Price": spenders_average,
                           "Total Purchase Value": spenders_total})

#Sort values by total purchase value
spenders_df = spenders_df.sort_values(["Total Purchase Value"], ascending = False)

#Format dataframe 
spenders_df["Average Purchase Price"]= spenders_df["Average Purchase Price"].astype(float).map("${:,.2f}".format)
spenders_df["Total Purchase Value"]= spenders_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)

#Align words to the left 
spenders_df = spenders_df.head(5).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])
spenders_df
# Out:
# <style  type="text/css" >
#     #T_87278150_a9eb_11ea_9238_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col2 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col2 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col0 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col1 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col2 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col0 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col1 {
#             text-align:  left;
#         }    #T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col2 {
#             text-align:  left;
#         }</style><table id="T_87278150_a9eb_11ea_9238_d0abd51aeb5d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_87278150_a9eb_11ea_9238_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_87278150_a9eb_11ea_9238_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col0" class="data row1 col0" >4</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_87278150_a9eb_11ea_9238_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_87278150_a9eb_11ea_9238_d0abd51aeb5dlevel0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_87278150_a9eb_11ea_9238_d0abd51aeb5dlevel0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col0" class="data row4 col0" >3</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_87278150_a9eb_11ea_9238_d0abd51aeb5drow4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %%
#Most popular item by Item ID
#Create a group by using Item ID
item = purchase_data.groupby(["Item ID", "Item Name"])

#Calculate purchase count 
purchase_count_id = item["Item ID"].count()

#Calculate item price 
item_price = item["Price"].mean()

#Calculate total purchase value
item_total_purchase = item["Price"].sum()

# Create dataframe with calculated values
items_df = pd.DataFrame({"Purchase Count": purchase_count_id,
                        "Item Price": item_price,
                        "Total Purchase Value": item_total_purchase})


#Format dataframe 
items_df["Item Price"] = items_df["Item Price"].astype(float).map("${:,.2f}".format)
items_df["Total Purchase Value"] = items_df["Total Purchase Value"].astype(float).map("${:,.2f}".format)


#Sort by purchase count column
items_df = items_df.sort_values(["Purchase Count"], ascending = False)

#Align words to the left 
items_df = items_df.head(5).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

items_df
# Out:
# <style  type="text/css" >
#     #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col2 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col2 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col0 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col1 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col2 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col0 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col1 {
#             text-align:  left;
#         }    #T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col2 {
#             text-align:  left;
#         }</style><table id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5d" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5dlevel1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col0" class="data row4 col0" >9</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_8aeb0a36_a9eb_11ea_bf98_d0abd51aeb5drow4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %%
#Most Profitable Item 
#Create a group by using Item ID
item2 = purchase_data.groupby(["Item ID", "Item Name"])

#Calculate purchase count 
purchase_count_id2 = item2["Item ID"].count()

#Calculate item price 
item_price2 = item2["Price"].mean()

#Calculate total purchase value
item_total_purchase2 = item2["Price"].sum()

# Create dataframe with calculated values
items_df2 = pd.DataFrame({"Purchase Count": purchase_count_id,
                        "Item Price": item_price,
                        "Total Purchase Value": item_total_purchase})

#Change the analysis to a numeric value for sorting
items_df2["Total Purchase Value"] = item2["Price"].sum()

#Sort by purchase count column
items_df2 = items_df2.sort_values(["Total Purchase Value"], ascending = False)

#Format dataframe 
items_df2["Item Price"] = items_df2["Item Price"].astype(float).map("${:,.2f}".format)
items_df2["Total Purchase Value"] = items_df2["Total Purchase Value"].astype(float).map("${:,.2f}".format)

#Align words to the left 
items_df2 = items_df2.head(5).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

items_df2
# Out:
# <style  type="text/css" >
#     #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5d th {
#           text-align: left;
#     }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col0 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col1 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col2 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col0 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col1 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col2 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col0 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col1 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col2 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col0 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col1 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col2 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col0 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col1 {
#             text-align:  left;
#         }    #T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col2 {
#             text-align:  left;
#         }</style><table id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5d" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5dlevel1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_8ffa110a_a9eb_11ea_892f_d0abd51aeb5drow4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
